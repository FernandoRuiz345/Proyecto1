# %% [markdown]
# # INTRODUCCION A WEBSCRAPING

# %% [markdown]
# En la red siempre encuentras informacion que copias y pegas con algo de dificultad, como por ejemplo, ver las estadisticas de Cristiano Ronaldo, ver los comentarios de la nueva pelicula, opiniones acerca del juego Left 4 dead 2, pero que pasa cuando los datos no son solo 1 o 2, sino que miles, para eso usaremos webscraping, programar en python para que se nos descargue la informacion como una base de datos en bruto.
#
# ## EXPRECIONES REGULARES:
#
# ¿Que es? Es una herramiento que usaran expreciones repetidas que seran clasificadas por patrones, como por ejemplo: los correos pato@gmail.com - fernando@hotmail.com.pe - cangrejo@yahooh.pe , que ¿Es lo mas comun aca para identificar cual es correo electronico?, usando el "@".
#
# (https://regex101.com/)
#
# https://en.wikipedia.org/wiki/Regular_expression
#
# https://docs.python.org/library/re.html
#
# ### Entendiendo expresiones regulares
#
# - Son muy  potentes y algo críptico.
# - Se puede decir que son un lenguaje en sí mismos.
# - Lenguaje de "caracteres de marcado" programando con caracteres.
#
# ^ Empata al inicio de la línea.
#
# | simbolo | descripcion |
# |---------|-------------|
# |^ | Empata al inicio de la línea. |
# | $ | Empata al fin de la línea.                                                       |
# | . | Empata con cualquier caracter (comodín).                                         |
# | \s | Empata con cualquier caracter que sea espacio en blanco.                            |
# | \S | Empata con un cualquier caracter que no sea espacio en blanco (opuesto de \s).  |
# | ? | Empata con el elemento anterior cero veces o una vez.                            |
# | * | Empata con el elemento anterior cero o más veces.                                |
# |*?| Empata con el elemento anterior cero o más veces, pero el menor número de veces que sea posible.|
# |+| Empata con el elemento anterior una o más veces-|
# |+?| Coincide con el elemento anterior una o más veces, pero el menor número de veces que sea posible.|
# |?| Empata con el elemento anterior cero veces o una vez.|
# |??| empata con el elemento anterior cero o una vez, pero el menor número de veces que sea posible.|
# |[aeiou]| Empata con un solo carácter siempre que ese carácter esté en el conjunto especificado.|
# |[a-z0-9]| Se puede especificar rangos de caracteres con el signo menos. Este ejemplo es un carácter único que debe ser una letra minúscula o un dígito.|
#
# ### Actividades: expresiones regulares (regex)
#
# Descargar el archivo *dr_chuck.txt*
# 1. Imprimir las líneas del archivo que contiene 'href=https:' usando métodos o funciones de caracteres.

# %%
datos = open("dr_chuck.txt")
for linea in datos:
    linea = linea.rstrip()
    if linea.find('href=https')>= 0:
        print(linea)
# Out:
# href=https://www.learnerprivacy.org>Podcast
# href=https://www.dr-chuck.com/csev-blog/>Blog
# href=https://www.twitter.com/drchuck/ target=_blank>@drchuck Twitter
# href=https://www.vimeo.com/17207620 target="_blank"

# %% [markdown]
# 2. Imprimir las líneas del archivo que empiecen con 't', seguido por dos caracteres cualquiera y luego seguidos por 's:'
# 3. Imprimir las líneas del archivo que contengan el signo @.
# 4. Contar el número de espacios en blanco por línea en el archivo
